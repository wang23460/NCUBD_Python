# %% [markdown]
# ### 0306 [HackMD](https://hackmd.io/TNUPGBL3SW2PjHSZOdWoVw#108%E8%AA%B2%E7%A8%8B%E5%85%A7%E5%AE%B9)
# ### **練習**
# ##### [ASCII](http://www.eion.com.tw/Blogger/?Pid=1128)
# ##### ord( c): 用來返回單個字符的ascii值（0-255）或者unicode數值（）。例如

# %%
# ord('d')
aa = {ord(c): None for c in ' '}
aa
# Out:
# {32: None}

# %%
datestr = '20180807'
r = requests.get('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + datestr + '&type=ALL')
r.text[1:1000]
# Out:
# '107年08月07日 大盤統計資訊"\r\n"指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",\r\n"寶島股價指數","12,648.36","-","38.59","-0.30",\r\n"發行量加權股價指數","10,983.44","-","40.66","-0.37",\r\n"臺灣公司治理100指數","6,125.83","-","39.60","-0.64",\r\n"臺灣50指數","8,290.50","-","37.69","-0.45",\r\n"臺灣中型100指數","8,237.21","-","24.77","-0.30",\r\n"臺灣資訊科技指數","10,513.30","-","117.69","-1.11",\r\n"臺灣發達指數","9,073.63","+","12.46","0.14",\r\n"臺灣高股息指數","6,199.90","+","4.37","0.07",\r\n"臺灣永續指數","5,260.64","-","30.19","-0.57",\r\n"臺灣就業99指數","6,511.29","-","1.32","-0.02",\r\n"臺灣高薪100指數","6,057.55","-","21.35","-0.35",\r\n"臺灣低波動高股息指數","1,654.66","-","2.83","-0.17",\r\n"未含金融保險股指數","9,279.75","-","39.07","-0.42",\r\n"未含電子股指數","15,057.68","-","43.51","-0.29",\r\n"未含金融電子股指數","12,796.90","-","50.18","-0.39",\r\n"小型股300指數","6,570.27","-","6.61","-0.10",\r\n"漲升股利150指數","6,210.29","-","18.73","-0.30",\r\n"漲升股利100指數","6,204.35","-","24.28","-0.39",\r\n"藍籌30指數","5,811.12","-","13.87","-0.24",\r\n"工業菁英30指數","6,343.90","-","37.21","-0.58",\r\n"電子菁英30指數",
# ...

# %%
# bb = r.text.split('\n')
# bb[15]
cc=[i.translate(aa)
   for i in bb 
   if len(i.split('",')) == 17 and i[0] != '=']
dd = StringIO('\n'.join(cc))

# %% [markdown]
# ###  **完整程式碼**

# %%
import requests
from io import StringIO#在内存中读写str。
import pandas as pd
import numpy as np

datestr = '20180807'
r = requests.get('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + datestr + '&type=ALL')

df = pd.read_csv(StringIO("\n".join([i.translate({ord(c): None for c in ' '}) 
    for i in r.text.split('\n') 
    if len(i.split('",')) == 17 and i[0] != '='])), header=0)

#"\n".join使用换行符链接列表.translate 過濾
df
# Out:
#      證券代號     證券名稱        成交股數   成交筆數           成交金額     開盤價     最高價     最低價  \
# 0    1101       台泥  27,766,431  5,118  1,119,603,560   40.40   40.60   40.15
# 1    1102       亞泥   6,204,191  3,002    255,051,845   41.00   41.60   40.70
# 2    1103       嘉泥   1,293,432    473     18,908,111   14.80   14.80   14.50
# 3    1104       環泥      85,772     58      1,708,655   19.95   19.95   19.90
# 4    1108       幸福     189,502     32      1,513,184    8.00    8.00    7.93
# 5    1109       信大     116,000     66      1,802,600   15.70   15.90   15.25
# 6    1110       東泥      12,183     10        169,943   13.90   14.00   13.90
# 7    1201       味全     879,966    497     21,228,678   24.30   24.35   24.00
# 8    1203       味王      17,017     13        439,088   25.65   26.00   25.65
# 9    1210       大成   1,819,355  1,152     74,955,527   41.00   41.70   40.70
# 10   1213       大飲      25,048     21        336,948   13.50   13.55   13.40
# ...

# %%
import requests
from io import StringIO#在内存中读写str。
import pandas as pd
import numpy as np

datestr = '20180807'
r = requests.get('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + datestr + '&type=ALL')
r.text[1:1000]
# Out:
# '107年08月07日 大盤統計資訊"\r\n"指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",\r\n"寶島股價指數","12,648.36","-","38.59","-0.30",\r\n"發行量加權股價指數","10,983.44","-","40.66","-0.37",\r\n"臺灣公司治理100指數","6,125.83","-","39.60","-0.64",\r\n"臺灣50指數","8,290.50","-","37.69","-0.45",\r\n"臺灣中型100指數","8,237.21","-","24.77","-0.30",\r\n"臺灣資訊科技指數","10,513.30","-","117.69","-1.11",\r\n"臺灣發達指數","9,073.63","+","12.46","0.14",\r\n"臺灣高股息指數","6,199.90","+","4.37","0.07",\r\n"臺灣永續指數","5,260.64","-","30.19","-0.57",\r\n"臺灣就業99指數","6,511.29","-","1.32","-0.02",\r\n"臺灣高薪100指數","6,057.55","-","21.35","-0.35",\r\n"臺灣低波動高股息指數","1,654.66","-","2.83","-0.17",\r\n"未含金融保險股指數","9,279.75","-","39.07","-0.42",\r\n"未含電子股指數","15,057.68","-","43.51","-0.29",\r\n"未含金融電子股指數","12,796.90","-","50.18","-0.39",\r\n"小型股300指數","6,570.27","-","6.61","-0.10",\r\n"漲升股利150指數","6,210.29","-","18.73","-0.30",\r\n"漲升股利100指數","6,204.35","-","24.28","-0.39",\r\n"藍籌30指數","5,811.12","-","13.87","-0.24",\r\n"工業菁英30指數","6,343.90","-","37.21","-0.58",\r\n"電子菁英30指數",
# ...

# %%
df = pd.read_csv(StringIO("\n".join([i.translate({ord(c): None for c in ' '}) 
    for i in r.text.split('\n') 
    if len(i.split('",')) == 17 and i[0] != '='])), header=0)

# %%
aa= {ord(c): None for c in ' '}
aa
# Out:
# {32: None}

# %%
wbb=r.text.split('\n') 
bb
# Out:
# ['"107年08月07日 大盤統計資訊"\r',
#  '"指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",\r',
#  '"寶島股價指數","12,648.36","-","38.59","-0.30",\r',
#  '"發行量加權股價指數","10,983.44","-","40.66","-0.37",\r',
#  '"臺灣公司治理100指數","6,125.83","-","39.60","-0.64",\r',
#  '"臺灣50指數","8,290.50","-","37.69","-0.45",\r',
#  '"臺灣中型100指數","8,237.21","-","24.77","-0.30",\r',
#  '"臺灣資訊科技指數","10,513.30","-","117.69","-1.11",\r',
#  '"臺灣發達指數","9,073.63","+","12.46","0.14",\r',
#  '"臺灣高股息指數","6,199.90","+","4.37","0.07",\r',
#  '"臺灣永續指數","5,260.64","-","30.19","-0.57",\r',
#  '"臺灣就業99指數","6,511.29","-","1.32","-0.02",\r',
#  '"臺灣高薪100指數","6,057.55","-","21.35","-0.35",\r',
#  '"臺灣低波動高股息指數","1,654.66","-","2.83","-0.17",\r',
#  '"未含金融保險股指數","9,279.75","-","39.07","-0.42",\r',
#  '"未含電子股指數","15,057.68","-","43.51","-0.29",\r',
#  '"未含金融電子股指數","12,796.90","-","50.18","-0.39",\r',
#  '"小型股300指數","6,570.27","-","6.61","-0.10",\r',
#  '"漲升股利150指數","6,210.29","-","18.73","-0.30",\r',
#  '"漲升股利100指數","6,204.35","-","24.28","-0.39",\r',
# ...

# %%
cc=[i.translate(aa)
   for i in bb 
   if len(i.split('",')) == 17 and i[0] != '=']
cc
# Out:
# ['"證券代號","證券名稱","成交股數","成交筆數","成交金額","開盤價","最高價","最低價","收盤價","漲跌(+/-)","漲跌價差","最後揭示買價","最後揭示買量","最後揭示賣價","最後揭示賣量","本益比",\r',
#  '"1101","台泥","27,766,431","5,118","1,119,603,560","40.40","40.60","40.15","40.15","-","0.20","40.15","277","40.20","1","17.53",\r',
#  '"1102","亞泥","6,204,191","3,002","255,051,845","41.00","41.60","40.70","41.10","+","0.10","41.10","33","41.15","1","19.39",\r',
#  '"1103","嘉泥","1,293,432","473","18,908,111","14.80","14.80","14.50","14.55","-","0.20","14.50","61","14.55","14","8.08",\r',
#  '"1104","環泥","85,772","58","1,708,655","19.95","19.95","19.90","19.90","-","0.05","19.90","16","19.95","19","11.50",\r',
#  '"1108","幸福","189,502","32","1,513,184","8.00","8.00","7.93","8.00","","0.00","8.00","7","8.01","10","0.00",\r',
#  '"1109","信大","116,000","66","1,802,600","15.70","15.90","15.25","15.60","-","0.15","15.45","1","15.70","1","9.69",\r',
# ...

# %%
for i in bb :
    if len (i.split('",'))==17:
        xx= i.translate(aa)
        print(xx)
# Out:
# "證券代號","證券名稱","成交股數","成交筆數","成交金額","開盤價","最高價","最低價","收盤價","漲跌(+/-)","漲跌價差","最後揭示買價","最後揭示買量","最後揭示賣價","最後揭示賣量","本益比",
# ="0050","元大台灣50","1,199,281","893","102,654,664","85.70","85.80","85.40","85.50","-","0.20","85.45","12","85.50","364","0.00",
# ="0051","元大中型100","10,000","6","342,110","34.27","34.27","34.16","34.16","-","0.12","34.16","18","34.30","3","0.00",
# ="0052","富邦科技","209,054","24","11,454,766","55.00","55.00","54.35","54.35","-","0.80","54.35","15","54.55","3","0.00",
# ="0053","元大電子","11,000","6","410,940","37.39","37.40","37.28","37.28","-","0.04","37.31","3","37.40","20","0.00",
# ="0054","元大台商50","3,000","3","75,000","24.94","25.03","24.94","25.03","+","0.19","24.98","20","25.02","3","0.00",
# ="0055","元大MSCI金融","35,000","18","627,660","17.97","17.97","17.90","17.90","-","0.01","17.90","1","17.94","2","0.00",
# ="0056","元大高股息","1,753,247","821","48,116,216","27.44","27.49","27.40","27.45","+","0.02","27.45","1,329","27.46","31","0.00",
# ...

# %%
for i in bb :
    if i[0] != '=':
        yy=i.translate(aa)
        print(yy)
# Out:
# "107年08月07日大盤統計資訊"
# "指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",
# "寶島股價指數","12,648.36","-","38.59","-0.30",
# "發行量加權股價指數","10,983.44","-","40.66","-0.37",
# "臺灣公司治理100指數","6,125.83","-","39.60","-0.64",
# "臺灣50指數","8,290.50","-","37.69","-0.45",
# "臺灣中型100指數","8,237.21","-","24.77","-0.30",
# "臺灣資訊科技指數","10,513.30","-","117.69","-1.11",
# "臺灣發達指數","9,073.63","+","12.46","0.14",
# "臺灣高股息指數","6,199.90","+","4.37","0.07",
# "臺灣永續指數","5,260.64","-","30.19","-0.57",
# "臺灣就業99指數","6,511.29","-","1.32","-0.02",
# "臺灣高薪100指數","6,057.55","-","21.35","-0.35",
# "臺灣低波動高股息指數","1,654.66","-","2.83","-0.17",
# "未含金融保險股指數","9,279.75","-","39.07","-0.42",
# "未含電子股指數","15,057.68","-","43.51","-0.29",
# "未含金融電子股指數","12,796.90","-","50.18","-0.39",
# "小型股300指數","6,570.27","-","6.61","-0.10",
# "漲升股利150指數","6,210.29","-","18.73","-0.30",
# "漲升股利100指數","6,204.35","-","24.28","-0.39",
# "藍籌30指數","5,811.12","-","13.87","-0.24",
# "工業菁英30指數","6,343.90","-","37.21","-0.58",
# ...

# %%
dd  = "\n".join(cc)
dd
# Out:
# '"證券代號","證券名稱","成交股數","成交筆數","成交金額","開盤價","最高價","最低價","收盤價","漲跌(+/-)","漲跌價差","最後揭示買價","最後揭示買量","最後揭示賣價","最後揭示賣量","本益比",\r\n"1101","台泥","27,766,431","5,118","1,119,603,560","40.40","40.60","40.15","40.15","-","0.20","40.15","277","40.20","1","17.53",\r\n"1102","亞泥","6,204,191","3,002","255,051,845","41.00","41.60","40.70","41.10","+","0.10","41.10","33","41.15","1","19.39",\r\n"1103","嘉泥","1,293,432","473","18,908,111","14.80","14.80","14.50","14.55","-","0.20","14.50","61","14.55","14","8.08",\r\n"1104","環泥","85,772","58","1,708,655","19.95","19.95","19.90","19.90","-","0.05","19.90","16","19.95","19","11.50",\r\n"1108","幸福","189,502","32","1,513,184","8.00","8.00","7.93","8.00","","0.00","8.00","7","8.01","10","0.00",\r\n"1109","信大","116,000","66","1,802,600","15.70","15.90","15.25","15.60","-","0.15","15.45","1","15.70","1","9.69",\r\n"1110","東泥","12,183","10","169,943","13.90","14.00","13.90","14.00","","0.00","13.85","35","14.00","27","155.56",\r\n"1201","味全","879,966","497","21,
# ...

# %%
ee = StringIO(dd)
dd
# Out:
# '"證券代號","證券名稱","成交股數","成交筆數","成交金額","開盤價","最高價","最低價","收盤價","漲跌(+/-)","漲跌價差","最後揭示買價","最後揭示買量","最後揭示賣價","最後揭示賣量","本益比",\r\n"1101","台泥","27,766,431","5,118","1,119,603,560","40.40","40.60","40.15","40.15","-","0.20","40.15","277","40.20","1","17.53",\r\n"1102","亞泥","6,204,191","3,002","255,051,845","41.00","41.60","40.70","41.10","+","0.10","41.10","33","41.15","1","19.39",\r\n"1103","嘉泥","1,293,432","473","18,908,111","14.80","14.80","14.50","14.55","-","0.20","14.50","61","14.55","14","8.08",\r\n"1104","環泥","85,772","58","1,708,655","19.95","19.95","19.90","19.90","-","0.05","19.90","16","19.95","19","11.50",\r\n"1108","幸福","189,502","32","1,513,184","8.00","8.00","7.93","8.00","","0.00","8.00","7","8.01","10","0.00",\r\n"1109","信大","116,000","66","1,802,600","15.70","15.90","15.25","15.60","-","0.15","15.45","1","15.70","1","9.69",\r\n"1110","東泥","12,183","10","169,943","13.90","14.00","13.90","14.00","","0.00","13.85","35","14.00","27","155.56",\r\n"1201","味全","879,966","497","21,
# ...

# %%
df=pd.read_csv(ee, header=0)
df.head()
# Out:
#    證券代號 證券名稱        成交股數   成交筆數           成交金額    開盤價    最高價    最低價    收盤價  \
# 0  1101   台泥  27,766,431  5,118  1,119,603,560  40.40  40.60  40.15  40.15
# 1  1102   亞泥   6,204,191  3,002    255,051,845  41.00  41.60  40.70  41.10
# 2  1103   嘉泥   1,293,432    473     18,908,111  14.80  14.80  14.50  14.55
# 3  1104   環泥      85,772     58      1,708,655  19.95  19.95  19.90  19.90
# 4  1108   幸福     189,502     32      1,513,184   8.00   8.00   7.93   8.00
#
#   漲跌(+/-)  漲跌價差 最後揭示買價 最後揭示買量 最後揭示賣價 最後揭示賣量    本益比  Unnamed: 16
# 0       -  0.20  40.15    277  40.20      1  17.53          NaN
# 1       +  0.10  41.10     33  41.15      1  19.39          NaN
# 2       -  0.20  14.50     61  14.55     14   8.08          NaN
# 3       -  0.05  19.90     16  19.95     19  11.50          NaN
# 4     NaN  0.00   8.00      7   8.01     10   0.00          NaN

# %%
df[pd.to_numeric(df['本益比'], errors='coerce') < 15]
# Out:
#        證券代號     證券名稱        成交股數   成交筆數           成交金額     開盤價     最高價  \
# 2      1103       嘉泥   1,293,432    473     18,908,111   14.80   14.80
# 3      1104       環泥      85,772     58      1,708,655   19.95   19.95
# 4      1108       幸福     189,502     32      1,513,184    8.00    8.00
# 5      1109       信大     116,000     66      1,802,600   15.70   15.90
# 8      1203       味王      17,017     13        439,088   25.65   26.00
# 9      1210       大成   1,819,355  1,152     74,955,527   41.00   41.70
# 10     1213       大飲      25,048     21        336,948   13.50   13.55
# 11     1215       卜蜂     507,382    412     28,850,436   57.10   57.20
# 12     1216       統一   7,304,678  4,272    538,949,172   74.20   74.70
# 19     1229       聯華   1,304,587    666     52,921,066   40.85   40.85
# 20     1231      聯華食     273,515    189     10,660,172   39.30   39.30
# 24     1235       興泰      10,800     11        422,830   38.10   39.95
# ...

# %%
df2 = df[pd.to_numeric(df['本益比'], errors='coerce') < 15].sort_values(by=['本益比', '收盤價'])
df2
# Out:
#        證券代號     證券名稱        成交股數   成交筆數         成交金額    開盤價    最高價    最低價  \
# 59     1418       東華         374      2        3,298     --     --     --
# 127    1538      正峰新         258    131        1,034     --     --     --
# 453    2712      遠雄來           0      0            0     --     --     --
# 768    6172       互億           0      0            0     --     --     --
# 888  910322   康師傅-DR           0      0            0     --     --     --
# 891  910708   恒大健-DR           0      0            0     --     --     --
# 889  910482   聖馬丁-DR     112,999     26       41,948   0.36   0.38   0.35
# 896  911619    耀傑-DR       4,000      1        3,320   0.83   0.83   0.83
# 902    9157  陽光能源-DR       9,000      3        9,670   1.12   1.12   1.04
# 895  911616    杜康-DR      12,000      6       13,320   1.09   1.15   1.09
# 898  911868  同方友友-DR      50,000      8       65,960   1.46   1.47   1.29
# 887    9103  美德醫療-DR     174,000     23      243,960   1.40   1.41   1.40
# ...

# %%
df.loc[(pd.to_numeric(df['本益比'], 
errors='coerce') < 15) & 
(pd.to_numeric(df['本益比'], 
errors='coerce') > 5) & 
(pd.to_numeric(df['收盤價'], errors='coerce') < 30) & 
(pd.to_numeric(df['成交筆數'], errors='coerce') > 100)]
# Out:
#      證券代號   證券名稱       成交股數 成交筆數        成交金額    開盤價    最高價    最低價    收盤價  \
# 2    1103     嘉泥  1,293,432  473  18,908,111  14.80  14.80  14.50  14.55
# 30   1304     台聚    364,188  212   5,015,520  13.75  13.85  13.70  13.80
# 31   1305     華夏  1,282,200  709  36,914,932  28.90  29.00  28.65  28.90
# 34   1309    台達化  2,193,757  621  31,530,937  14.15  14.55  14.10  14.50
# 35   1310     台苯  1,987,167  575  43,640,535  21.90  22.10  21.80  21.90
# 38   1313     聯成  1,520,056  472  27,606,816  18.10  18.30  18.00  18.25
# 55   1413     宏洲  1,117,142  397  14,773,858  13.65  13.65  13.00  13.15
# 71   1442     名軒    607,688  182  12,134,737  20.00  20.05  19.90  19.90
# 87   1463     強盛    330,000  186   5,849,750  17.65  17.90  17.60  17.85
# 128  1539     巨庭  1,834,300  982  44,382,730  23.90  24.65  23.40  23.90
# 144  1608     華榮    274,517  191   2,865,751  10.45  10.50  10.40  10.45
# 145  1609     大亞  1,531,766  553  20,978,800  13.75  13.80  13.60  13.70
# ...

# %%
df1_1=pd.to_numeric(df['本益比'], errors='coerce') < 15 
df1_2=pd.to_numeric(df['本益比'], errors='coerce') > 10
df2= df[df1_1&df1_2]
df2.sort_values('本益比')
# Out:
#      證券代號     證券名稱        成交股數    成交筆數           成交金額     開盤價     最高價     最低價  \
# 739  5607      遠雄港      73,000      34      1,228,600   16.80   16.90   16.80
# 281  2347       聯強   4,034,145   2,880    179,702,770   43.55   45.15   43.50
# 678  4722      國精化     164,844      58      5,184,858   31.40   31.60   31.30
# 114  1524       耿鼎     134,001      64      1,388,460   10.40   10.45   10.30
# 559  3052       夆典     201,087     102      1,868,657    9.30    9.40    9.25
# 908  9906      欣巴巴     200,032     112      2,666,413   13.10   13.70   13.10
# 484  2882      國泰金   5,006,672   2,075    263,723,349   52.80   53.00   52.50
# 115  1525       江申      28,500      31      2,039,099   72.00   72.00   71.10
# 116  1526       日馳      79,500      72      3,066,474   38.95   38.95   38.45
# 444  2636     台驊投控     797,237     331     19,426,410   24.15   24.50   24.10
# 834  6605       帝寶     119,200      96      9,182,000   77.50   77.50   76.40
# ...
