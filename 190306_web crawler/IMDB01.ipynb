# %% [markdown]
# ### **0306:IMDB**
# #### **練習**
# ##### [Beautiful Soup](https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/)
# ##### - **Findall : 看namelist的code**

# %%
#搜尋imdb 熱門電影 名稱（第一頁）
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://ppt.cc/fx3k8x")
bsObj = BeautifulSoup(html,'html.parser')
namelist = bsObj.findAll("td",{"class":"titleColumn"})

for a in range(0,1):
    for name in namelist:
        a+=1
        b=str(a)
        testa=[]
        testa=name.get_text().splitlines()
        output=testa[1]
        print(b+":"+output)
# Out:
# 1:Green Book
# 2:Bohemian Rhapsody
# 3:A Star Is Born
# 4:The Favourite
# 5:Alita: Battle Angel
# 6:Roma
# 7:Spider-Man: Into the Spider-Verse
# 8:Captain Marvel
# 9:The Irishman
# 10:Dark Phoenix
# 11:Rocketman
# 12:BlacKkKlansman
# 13:How to Train Your Dragon: The Hidden World
# 14:Fighting with My Family
# 15:Vice
# 16:Isn't It Romantic
# 17:Black Panther
# 18:Avengers: Endgame
# 19:Instant Family
# 20:Serenity
# 21:Once Upon a Time in Hollywood
# 22:Hellboy
# 23:Can You Ever Forgive Me?
# 24:Joker
# 25:Greta
# 26:The Lion King
# 27:Free Solo
# 28:Skin
# 29:If Beale Street Could Talk
# 30:Mary Queen of Scots
# 31:Fantastic Beasts: The Crimes of Grindelwald
# 32:After
# 33:Pokémon Detective Pikachu
# 34:Polar
# 35:Cold Pursuit
# 36:Us
# 37:Aquaman
# 38:Ralph Breaks the Internet
# 39:Overlord
# 40:Climax
# 41:Avengers: Infinity War
# 42:First Man
# 43:Robin Hood
# 44:Aladdin
# 45:The Ballad of Buster Scruggs
# 46:The Wife
# 47:Paddleton
# 48:Creed II
# 49:Gully Boy
# ...

# %%
html

# %%
bsObj
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Most Popular Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
# ...

# %% [markdown]
# #### **[IMDB原始碼](https://www.imdb.com/chart/moviemeter?ref_=nv_mv_mpm)**
# ##### 用FINDALL找電影名稱

# %%
#使用findall找到電影名稱(看css原始碼)
namelist = bsObj.findAll("td",{"class":"titleColumn"})
namelist
# Out:
# [<td class="titleColumn">
#  <a href="/title/tt6966692/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=ea4e08e1-c8a3-47b5-ac3a-75026647c16e&amp;pf_rd_r=PW2KAZEEF8Z9G9NCTQB1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_1" title="Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali">Green Book</a>
#  <span class="secondaryInfo">(2018)</span>
#  <div class="velocity">1
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  3)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt1727824/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=ea4e08e1-c8a3-47b5-ac3a-75026647c16e&amp;pf_rd_r=PW2KAZEEF8Z9G9NCTQB1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_2" title="Bryan Singer (dir.), Rami Malek, Lucy Boynton">Bohemian Rhapsody</a>
#  <span class="secondaryInfo">(2018)</span>
#  <div class="velocity">2
#  (no change)
#  </div>
#  </td>, <td class="titleColumn">
# ...

# %% [markdown]
# #### **繼續處理(還是很亂)**

# %%
#搜尋imdb 熱門電影 名稱（第一頁）
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://ppt.cc/fx3k8x")
bsObj = BeautifulSoup(html,'html.parser')
namelist = bsObj.findAll("td",{"class":"titleColumn"})

for name in namelist:
    testa=[]
    testa=name.get_text().splitlines()
    output=testa[1]
    print(output)
# Out:
# Green Book
# Bohemian Rhapsody
# A Star Is Born
# The Favourite
# Alita: Battle Angel
# Roma
# Spider-Man: Into the Spider-Verse
# Captain Marvel
# The Irishman
# Dark Phoenix
# Rocketman
# BlacKkKlansman
# How to Train Your Dragon: The Hidden World
# Fighting with My Family
# Vice
# Isn't It Romantic
# Black Panther
# Avengers: Endgame
# Instant Family
# Serenity
# Once Upon a Time in Hollywood
# Hellboy
# Can You Ever Forgive Me?
# Joker
# Greta
# The Lion King
# Free Solo
# Skin
# If Beale Street Could Talk
# Mary Queen of Scots
# Fantastic Beasts: The Crimes of Grindelwald
# After
# Pokémon Detective Pikachu
# Polar
# Cold Pursuit
# Us
# Aquaman
# Ralph Breaks the Internet
# Overlord
# Climax
# Avengers: Infinity War
# First Man
# Robin Hood
# Aladdin
# The Ballad of Buster Scruggs
# The Wife
# Paddleton
# Creed II
# Gully Boy
# Period. End of Sentence.
# Mortal Engines
# Deadpool 2
# The Dirt
# Glass
# Happy Death Day 2U
# The Lego Movie 2: The Second Part
# A Star Is Born
# ...

# %%
testa
# Out:
# ['', 'Apollo 11', '(2019)', '100', '(', '', '285)', '']

# %%
#搜尋imdb 熱門電影 名稱（第一頁）
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://ppt.cc/fx3k8x")
bsObj = BeautifulSoup(html,'html.parser')
namelist = bsObj.findAll("td",{"class":"titleColumn"})

for a in range(0,1):
    for name in namelist:
        a+=1
        b=str(a)
        testa=[]
        testa=name.get_text().splitlines()
        output=testa[1]
        print(b+":"+output)
# Out:
# 1:Green Book
# 2:Bohemian Rhapsody
# 3:A Star Is Born
# 4:The Favourite
# 5:Alita: Battle Angel
# 6:Roma
# 7:Spider-Man: Into the Spider-Verse
# 8:Captain Marvel
# 9:The Irishman
# 10:Dark Phoenix
# 11:Rocketman
# 12:BlacKkKlansman
# 13:How to Train Your Dragon: The Hidden World
# 14:Fighting with My Family
# 15:Vice
# 16:Isn't It Romantic
# 17:Black Panther
# 18:Avengers: Endgame
# 19:Instant Family
# 20:Serenity
# 21:Once Upon a Time in Hollywood
# 22:Hellboy
# 23:Can You Ever Forgive Me?
# 24:Joker
# 25:Greta
# 26:The Lion King
# 27:Free Solo
# 28:Skin
# 29:If Beale Street Could Talk
# 30:Mary Queen of Scots
# 31:Fantastic Beasts: The Crimes of Grindelwald
# 32:After
# 33:Pokémon Detective Pikachu
# 34:Polar
# 35:Cold Pursuit
# 36:Us
# 37:Aquaman
# 38:Ralph Breaks the Internet
# 39:Overlord
# 40:Climax
# 41:Avengers: Infinity War
# 42:First Man
# 43:Robin Hood
# 44:Aladdin
# 45:The Ballad of Buster Scruggs
# 46:The Wife
# 47:Paddleton
# 48:Creed II
# 49:Gully Boy
# ...

# %%
# 爬 評論(name)，使用time 來緩衝 load more 
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
ELE = []

browser = webdriver.Chrome()
browser.get('https://www.imdb.com/title/tt4154756/reviews?ref_=tt_ov_rt')

for i in range(1, 5):
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    for ele in soup.select('.display-name-link'):
        print(ele.text)

    browser.find_element_by_xpath('//div[@class="ipl-load-more ipl-load-more--loaded"]').click()
    time.sleep(3)
browser.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-6805e6d99640> in <module>()
#       1 # 爬 評論(name)，使用time 來緩衝 load more
# ----> 2 from selenium import webdriver
#       3 from selenium.webdriver.common.by import By
#       4 from bs4 import BeautifulSoup
#       5 import time
#
# ModuleNotFoundError: No module named 'selenium'

# %%
#test 
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://www.imdb.com/movies-in-theaters/?ref_=nv_tp_inth_1')
bs = BeautifulSoup(html, "html.parser")
nameList = bs.findAll('div', {"class":"outline"})

i=0
while (i<1):
    print (name)
    i=i+1
for name in nameList:
    print(name.get_text())

# %%
# test 
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re
html = urlopen("https://www.imdb.com/movies-in-theaters/?ref_=nv_tp_inth_1")
bsObj = BeautifulSoup(html)
images = bsObj.findAll('img')  # all img
images2 = bsObj.findAll('img',{"class":"poster shadowed"}) # 熱門img

for img in images2:
    src=img['src']
    img_url=src
    print(img_url)

# %%
#test 
#檢查 文件是否在某位置
import os
fp_path = '/Users/yhdeng/desktop/test1.py'
 
if ( os.path.exists(fp_path)):
    print("Path exists!")
else:
    print("Path not found!")

# %%
#test
import os
path = '/Users/yhdeng/desktop/test2.py'
try:
    if  os.path.exists(path):
        with open(path,'wb') as f :
            f.write(r.content)
            f.close()
            print("文件save")
    else:
        print("已存在")
except:
    print("失敗ＱＱ")

# %%
# 爬 評論(name)，使用time 來緩衝 load more 
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
ELE = []

browser = webdriver.Chrome()
browser.get('https://www.imdb.com/title/tt4154756/reviews?ref_=tt_ov_rt')

for i in range(1, 5):
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    for ele in soup.findAll('div', {'class': 'lister-item-content'}):
        a=ele.findAll('a')[0]
        print(a.text.strip())
    browser.find_element_by_xpath('//div[@class="ipl-load-more ipl-load-more--loaded"]').click()
    time.sleep(3)
    
browser.close()
